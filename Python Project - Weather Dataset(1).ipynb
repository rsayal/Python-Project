# %% [markdown]
# ## Weather Dataset

# %% [markdown]
# This weather dataset is a time series dataset with per hour information about the weather conditions at a particular location. It records Temperature, Dew Point Temperature, Relative Humidity, Wind Speed, Visibility, Pressure and Conditions.
#
# The data is available as a CSV file. We are going to analyze the dataset using Python's Pandas and Matplotlib library.

# %% [markdown]
# ### Import the Dataset

# %% [markdown]
# First, we import Python's Pandas and Matplotlib library and read in the data file that we imported into Jupyter Notebook.
# pd.read_csv() is a function from the pandas library that reads in a CSV file and creates a DataFrame (df)

# %%
import pandas as pd
import matplotlib.pyplot as plt

df = pd.read_csv('Weather Dataset.csv')

# %% [markdown]
# ### Display the Dataset

# %% [markdown]
# We can display the entire dataset typing in df, the variable created earlier providing an overview for all the rows and columns present in the dataframe.

# %%
df
# Out:
#              Date/Time  Temp_C  Dew Point Temp_C  Rel Hum_%  Wind Speed_km/h  \
# 0        1/1/2012 0:00    -1.8              -3.9         86                4
# 1        1/1/2012 1:00    -1.8              -3.7         87                4
# 2        1/1/2012 2:00    -1.8              -3.4         89                7
# 3        1/1/2012 3:00    -1.5              -3.2         88                6
# 4        1/1/2012 4:00    -1.5              -3.3         88                7
# ...                ...     ...               ...        ...              ...
# 8779  12/31/2012 19:00     0.1              -2.7         81               30
# 8780  12/31/2012 20:00     0.2              -2.4         83               24
# 8781  12/31/2012 21:00    -0.5              -1.5         93               28
# 8782  12/31/2012 22:00    -0.2              -1.8         89               28
# 8783  12/31/2012 23:00     0.0              -2.1         86               30
#
# ...

# %% [markdown]
# ### How many rows and columns are there in the dataset.

# %% [markdown]
# df.shape is an attribute that returns the number of rows and columns in the dataset. df.shape[0] returns the total number of rows. df.shape[1] returns the total number of columns.

# %%
print('There are', df.shape[0], 'rows and',df.shape[1],'columns in this dataset.')
# Out:
# There are 8784 rows and 8 columns in this dataset.

# %% [markdown]
# ### Display The first 10 records from the dataset

# %% [markdown]
# df.head(10) is a method that returns the first 10 records from the dataset

# %%
df.head(10)
# Out:
#        Date/Time  Temp_C  Dew Point Temp_C  Rel Hum_%  Wind Speed_km/h  \
# 0  1/1/2012 0:00    -1.8              -3.9         86                4
# 1  1/1/2012 1:00    -1.8              -3.7         87                4
# 2  1/1/2012 2:00    -1.8              -3.4         89                7
# 3  1/1/2012 3:00    -1.5              -3.2         88                6
# 4  1/1/2012 4:00    -1.5              -3.3         88                7
# 5  1/1/2012 5:00    -1.4              -3.3         87                9
# 6  1/1/2012 6:00    -1.5              -3.1         89                7
# 7  1/1/2012 7:00    -1.4              -3.6         85                7
# 8  1/1/2012 8:00    -1.4              -3.6         85                9
# 9  1/1/2012 9:00    -1.3              -3.1         88               15
#
#    Visibility_km  Press_kPa               Weather
# 0            8.0     101.24                   Fog
# 1            8.0     101.24                   Fog
# ...

# %% [markdown]
# ### Display the last 10 records from the dataset

# %% [markdown]
# df.tail(10) is a method that returns the last 10 records from the dataset.

# %%
df.tail(10)
# Out:
#              Date/Time  Temp_C  Dew Point Temp_C  Rel Hum_%  Wind Speed_km/h  \
# 8774  12/31/2012 14:00    -3.4              -5.7         84                6
# 8775  12/31/2012 15:00    -2.3              -4.6         84                9
# 8776  12/31/2012 16:00    -1.4              -4.0         82               13
# 8777  12/31/2012 17:00    -1.1              -3.3         85               19
# 8778  12/31/2012 18:00    -1.3              -3.1         88               17
# 8779  12/31/2012 19:00     0.1              -2.7         81               30
# 8780  12/31/2012 20:00     0.2              -2.4         83               24
# 8781  12/31/2012 21:00    -0.5              -1.5         93               28
# 8782  12/31/2012 22:00    -0.2              -1.8         89               28
# 8783  12/31/2012 23:00     0.0              -2.1         86               30
#
#       Visibility_km  Press_kPa Weather
# 8774           11.3     100.57    Snow
# 8775            9.7     100.47    Snow
# ...

# %% [markdown]
# ### State the DataType of Each Column

# %% [markdown]
# df.dtypes is an attribute that returns information about the data type present in each column of the DataFrame.
# It provides insight into whether each column contains integers, strings, dates, etc.
#
# To add column names to a DataFrame first use the reset_index method() to convert a series into a dataframe and then use the .columns method.

# %%
df.dtypes

#Convert Series to DataFrame

dtypes = df.dtypes.reset_index()


# Add column names 
dtypes.columns = ['Column Name', 'Data Type']


print(dtypes)
# Out:
#         Column Name Data Type
# 0         Date/Time    object
# 1            Temp_C   float64
# 2  Dew Point Temp_C   float64
# 3         Rel Hum_%     int64
# 4   Wind Speed_km/h     int64
# 5     Visibility_km   float64
# 6         Press_kPa   float64
# 7           Weather    object

# %% [markdown]
# ### Q1. How many unique values are in the weather column.

# %% [markdown]
# .nunique() is a method in pandas that returns the number of unique values in a Series or DataFrame

# %%
print("There are ", df['Weather'].nunique(), 'unique values in the weather column')
# Out:
# There are  50 unique values in the weather column

# %% [markdown]
# ### Q2. What are the Unique Values in the Weather column

# %% [markdown]
# .unique() method in pandas returns the actual unique values present in a particular Series or DataFrame.

# %%
print("The unique values in the Weather column are the following: ")
print()
print(df['Weather'].unique())
# Out:
# The unique values in the Weather column are the following:
#
# ['Fog' 'Freezing Drizzle,Fog' 'Mostly Cloudy' 'Cloudy' 'Rain'
#  'Rain Showers' 'Mainly Clear' 'Snow Showers' 'Snow' 'Clear'
#  'Freezing Rain,Fog' 'Freezing Rain' 'Freezing Drizzle' 'Rain,Snow'
#  'Moderate Snow' 'Freezing Drizzle,Snow' 'Freezing Rain,Snow Grains'
#  'Snow,Blowing Snow' 'Freezing Fog' 'Haze' 'Rain,Fog' 'Drizzle,Fog'
#  'Drizzle' 'Freezing Drizzle,Haze' 'Freezing Rain,Haze' 'Snow,Haze'
#  'Snow,Fog' 'Snow,Ice Pellets' 'Rain,Haze' 'Thunderstorms,Rain'
#  'Thunderstorms,Rain Showers' 'Thunderstorms,Heavy Rain Showers'
#  'Thunderstorms,Rain Showers,Fog' 'Thunderstorms' 'Thunderstorms,Rain,Fog'
#  'Thunderstorms,Moderate Rain Showers,Fog' 'Rain Showers,Fog'
#  'Rain Showers,Snow Showers' 'Snow Pellets' 'Rain,Snow,Fog'
#  'Moderate Rain,Fog' 'Freezing Rain,Ice Pellets,Fog'
#  'Drizzle,Ice Pellets,Fog' 'Drizzle,Snow' 'Rain,Ice Pellets'
#  'Drizzle,Snow,Fog' 'Rain,Snow Grains' 'Rain,Snow,Ice Pellets'
# ...

# %% [markdown]
# ### Q3, Convert datetime column from object to datetime  datatype.

# %% [markdown]
# pd.to_datetime() is a pandas method that converts a given input, such as a string or another datetime-like object,
# into a pandas datetime format

# %%
df['Date/Time'] = pd.to_datetime(df['Date/Time'])

# %% [markdown]
# ### Q4. Rename Date/Time, Temp_C, Visibility_km columns to DateTime, Temperature(C), Visibility (km/h)

# %% [markdown]
# df.rename() method in pandas is used to rename columns in a DataFrame.
# to specify new names for the columns, you pass a dictionary where the keys are the
# current column names and the values are the new column names, enclosed within curly braces {}

# %%
df.rename(columns = {'Date/Time':'DateTime','Temp_C':'Temperature (C)','Visibility_km':'Visibility (km/h)'})
# Out:
#                 DateTime  Temperature (C)  Dew Point Temp_C  Rel Hum_%  \
# 0    2012-01-01 00:00:00             -1.8              -3.9         86
# 1    2012-01-01 01:00:00             -1.8              -3.7         87
# 2    2012-01-01 02:00:00             -1.8              -3.4         89
# 3    2012-01-01 03:00:00             -1.5              -3.2         88
# 4    2012-01-01 04:00:00             -1.5              -3.3         88
# ...                  ...              ...               ...        ...
# 8779 2012-12-31 19:00:00              0.1              -2.7         81
# 8780 2012-12-31 20:00:00              0.2              -2.4         83
# 8781 2012-12-31 21:00:00             -0.5              -1.5         93
# 8782 2012-12-31 22:00:00             -0.2              -1.8         89
# 8783 2012-12-31 23:00:00              0.0              -2.1         86
#
#       Wind Speed_km/h  Visibility (km/h)  Press_kPa               Weather
# ...

# %% [markdown]
# ### Q5. How many times was it snowing and the temperature was less then -5 C.

# %%
snow = (df['Weather'] == 'Snow') & (df['Temp_C'] < -5)
snowing = df[snow]
snowing
# Out:
#                Date/Time  Temp_C  Dew Point Temp_C  Rel Hum_%  \
# 55   2012-01-03 07:00:00   -14.0             -19.5         63
# 84   2012-01-04 12:00:00   -13.7             -21.7         51
# 86   2012-01-04 14:00:00   -11.3             -19.0         53
# 87   2012-01-04 15:00:00   -10.2             -16.3         61
# 88   2012-01-04 16:00:00    -9.4             -15.5         61
# ...                  ...     ...               ...        ...
# 8670 2012-12-27 06:00:00    -6.8              -8.1         90
# 8671 2012-12-27 07:00:00    -6.5              -7.6         92
# 8769 2012-12-31 09:00:00    -8.1              -9.6         89
# 8771 2012-12-31 11:00:00    -6.7              -7.9         91
# 8772 2012-12-31 12:00:00    -5.8              -7.5         88
#
#       Wind Speed_km/h  Visibility_km  Press_kPa Weather
# 55                 19           25.0     100.95    Snow
# 84                 11           24.1     101.25    Snow
# ...

# %% [markdown]
# A new DataFrame called "snowing" is created that contains rows from the
# original DataFrame "df" where the conditions for both snowing and temperature below -5 are met.

# %% [markdown]
# ### Q6. How many times was the weather foggy in this dataset.

# %% [markdown]
# groupby function in pandas groups the data points (i.e. rows) based on the distinct values in the given column.
# In this instance, groupby function returns all instances where the weather shows 'fog' in the forecast.

# %%
df.groupby('Weather').get_group('Fog')
# Out:
#                Date/Time  Temp_C  Dew Point Temp_C  Rel Hum_%  \
# 0    2012-01-01 00:00:00    -1.8              -3.9         86
# 1    2012-01-01 01:00:00    -1.8              -3.7         87
# 4    2012-01-01 04:00:00    -1.5              -3.3         88
# 5    2012-01-01 05:00:00    -1.4              -3.3         87
# 6    2012-01-01 06:00:00    -1.5              -3.1         89
# ...                  ...     ...               ...        ...
# 8716 2012-12-29 04:00:00   -16.0             -17.2         90
# 8717 2012-12-29 05:00:00   -14.8             -15.9         91
# 8718 2012-12-29 06:00:00   -13.8             -15.3         88
# 8719 2012-12-29 07:00:00   -14.8             -16.4         88
# 8722 2012-12-29 10:00:00   -12.0             -13.3         90
#
#       Wind Speed_km/h  Visibility_km  Press_kPa Weather
# 0                   4            8.0     101.24     Fog
# 1                   4            8.0     101.24     Fog
# ...

# %%
#Another way to solve this problem is by filtering the weather column in this dataframe 
#so that only values with the word 'Fog' appears in the result. 

df[df['Weather'] == 'Fog']
# Out:
#                Date/Time  Temp_C  Dew Point Temp_C  Rel Hum_%  \
# 0    2012-01-01 00:00:00    -1.8              -3.9         86
# 1    2012-01-01 01:00:00    -1.8              -3.7         87
# 4    2012-01-01 04:00:00    -1.5              -3.3         88
# 5    2012-01-01 05:00:00    -1.4              -3.3         87
# 6    2012-01-01 06:00:00    -1.5              -3.1         89
# ...                  ...     ...               ...        ...
# 8716 2012-12-29 04:00:00   -16.0             -17.2         90
# 8717 2012-12-29 05:00:00   -14.8             -15.9         91
# 8718 2012-12-29 06:00:00   -13.8             -15.3         88
# 8719 2012-12-29 07:00:00   -14.8             -16.4         88
# 8722 2012-12-29 10:00:00   -12.0             -13.3         90
#
#       Wind Speed_km/h  Visibility_km  Press_kPa Weather
# 0                   4            8.0     101.24     Fog
# 1                   4            8.0     101.24     Fog
# ...

# %% [markdown]
# The above code will work only for the word 'Fog'. However, Python is case sensitive, So, the code as written will only
# filter rows where the 'Weather' column value is only the word 'Fog' with a capital 'F'.
# If the values in the 'Weather' column are mixed-case (e.g., 'Fog', 'fog', 'FOG'), this code won't capture all the variations.
# If you want to filter for rows where the 'Weather' column contains the word 'fog'
# regardless of case, you can use the .str.contains() method along with the case parameter set to False:

# %%
df[df['Weather'].str.contains('fog', case=False)]
# Out:
#                Date/Time  Temp_C  Dew Point Temp_C  Rel Hum_%  \
# 0    2012-01-01 00:00:00    -1.8              -3.9         86
# 1    2012-01-01 01:00:00    -1.8              -3.7         87
# 2    2012-01-01 02:00:00    -1.8              -3.4         89
# 3    2012-01-01 03:00:00    -1.5              -3.2         88
# 4    2012-01-01 04:00:00    -1.5              -3.3         88
# ...                  ...     ...               ...        ...
# 8739 2012-12-30 03:00:00    -9.1             -10.4         90
# 8740 2012-12-30 04:00:00    -9.3             -10.6         90
# 8741 2012-12-30 05:00:00    -9.1             -10.4         90
# 8742 2012-12-30 06:00:00    -9.3             -10.8         89
# 8770 2012-12-31 10:00:00    -7.4              -8.9         89
#
#       Wind Speed_km/h  Visibility_km  Press_kPa               Weather
# 0                   4            8.0     101.24                   Fog
# 1                   4            8.0     101.24                   Fog
# ...

# %% [markdown]
# ### Q7. How many times was the windspeed between 8 to 10 km/h in this dataset.

# %%
df[df['Wind Speed_km/h'].between(8,10)]
# Out:
#                Date/Time  Temp_C  Dew Point Temp_C  Rel Hum_%  \
# 5    2012-01-01 05:00:00    -1.4              -3.3         87
# 8    2012-01-01 08:00:00    -1.4              -3.6         85
# 10   2012-01-01 10:00:00    -1.0              -2.3         91
# 12   2012-01-01 12:00:00    -0.2              -2.0         88
# 77   2012-01-04 05:00:00   -18.6             -24.0         62
# ...                  ...     ...               ...        ...
# 8737 2012-12-30 01:00:00    -9.4             -10.5         92
# 8738 2012-12-30 02:00:00    -9.3             -10.4         92
# 8762 2012-12-31 02:00:00   -10.1             -13.4         77
# 8771 2012-12-31 11:00:00    -6.7              -7.9         91
# 8775 2012-12-31 15:00:00    -2.3              -4.6         84
#
#       Wind Speed_km/h  Visibility_km  Press_kPa       Weather
# 5                   9            6.4     101.27           Fog
# 8                   9            8.0     101.23           Fog
# ...

# %% [markdown]
# df[df['Wind Speed_km/h'].between(8, 10)] will filter the DataFrame df to include only the rows where the 'Wind Speed_km/h'
# column's values are between 8 and 10 kilometers per hour

# %% [markdown]
# ### Q8. How many times was the windspeed exactly 6 km/h in this dataset

# %%
df[df['Wind Speed_km/h'] == 6]
# Out:
#                Date/Time  Temp_C  Dew Point Temp_C  Rel Hum_%  \
# 3    2012-01-01 03:00:00    -1.5              -3.2         88
# 94   2012-01-04 22:00:00    -9.5             -12.7         77
# 95   2012-01-04 23:00:00    -9.6             -12.6         79
# 102  2012-01-05 06:00:00    -8.2             -10.7         82
# 144  2012-01-07 00:00:00    -8.7             -11.7         79
# ...                  ...     ...               ...        ...
# 8644 2012-12-26 04:00:00   -13.1             -14.7         88
# 8716 2012-12-29 04:00:00   -16.0             -17.2         90
# 8763 2012-12-31 03:00:00   -11.8             -14.4         81
# 8765 2012-12-31 05:00:00   -10.2             -12.4         84
# 8774 2012-12-31 14:00:00    -3.4              -5.7         84
#
#       Wind Speed_km/h  Visibility_km  Press_kPa               Weather
# 3                   6            4.0     101.27  Freezing Drizzle,Fog
# 94                  6            9.7     100.50                  Snow
# ...

# %% [markdown]
# ### Q9. Find out if there are any null values in this dataset.

# %% [markdown]
#  df.isnull().sum() is a pandas DataFrame method that computes the sum of null values in each column of the DataFrame.

# %%
df.isnull().sum()
# Out:
# Date/Time           0
# Temp_C              0
# Dew Point Temp_C    0
# Rel Hum_%           0
# Wind Speed_km/h     0
# Visibility_km       0
# Press_kPa           0
# Weather             0
# dtype: int64

# %% [markdown]
# df.notnull().sum() is a pandas DataFrame method that computes the sum of non-null values in each column of the DataFrame

# %%
df.notnull().sum()
# Out:
# Date/Time           8784
# Temp_C              8784
# Dew Point Temp_C    8784
# Rel Hum_%           8784
# Wind Speed_km/h     8784
# Visibility_km       8784
# Press_kPa           8784
# Weather             8784
# dtype: int64

# %%
print('There are no null values in the dataset')
# Out:
# There are no null values in the dataset

# %% [markdown]
# ### Q10. What is the mean visibility?

# %%
df['Visibility_km'].mean()
# Out:
# 27.664446721311478

# %% [markdown]
# df['Visibility_km'].mean() calculates the mean (average) value of the 'Visibility_km' column in the DataFrame "df"

# %% [markdown]
# ### Q11. What was the coldest temperature on record in this dataset?

# %% [markdown]
# df['Temp_C'].idxmin() finds the index of the row where the coldest temperature (Temp_C column) occurs.
# df.loc[df['Temp_C'].idxmin()] uses the loc method to retrieve the entire row (record)
# of data corresponding to the coldest temperature

# %%
print(df['Temp_C'].min())
# Out:
# -23.3

# %%
coldest_row = df.loc[df['Temp_C'].idxmin()]
print(coldest_row)
# Out:
# Date/Time           2012-01-15 08:00:00
# Temp_C                            -23.3
# Dew Point Temp_C                  -28.5
# Rel Hum_%                            62
# Wind Speed_km/h                       7
# Visibility_km                      24.1
# Press_kPa                        102.45
# Weather                           Clear
# Name: 344, dtype: object

# %%
print('The coldest temperature on record in this dataset was', df['Temp_C'].min(), 'on January 15 2012' )
# Out:
# The coldest temperature on record in this dataset was -23.3 on January 15 2012

# %% [markdown]
# ### Q12. What was the warmest temperature on record in this dataset?

# %% [markdown]
# df.loc combined with the idxmax() method locates
# the exact row in the DataFrame where the temperature was the highest.
#
# df.loc is used for label-based indexing to access rows and columns in a DataFrame.
# idxmax() and idxmin() are methods of pandas Series that return the index (label) of the maximum and minimum values in the Series, respectively.

# %%
df['Temp_C'].max()
# Out:
# 33.0

# %%
warmest_temperature = df.loc[df['Temp_C'].idxmax()]
print(warmest_temperature)
# Out:
# Date/Time           2012-06-21 15:00:00
# Temp_C                             33.0
# Dew Point Temp_C                   19.0
# Rel Hum_%                            44
# Wind Speed_km/h                      24
# Visibility_km                      24.1
# Press_kPa                         100.2
# Weather                    Mainly Clear
# Name: 4143, dtype: object

# %%
print('The warmest temperature on record is',df['Temp_C'].max(), 'C on June 21st 2012')
# Out:
# The warmest temperature on record is 33.0 C on June 21st 2012

# %% [markdown]
# ### Q13. Find all instances where temperature is below -5 C, Wind Speed is between 5 to 10 km/h and visibility is less then 10 km/h

# %%
df[ (df['Temp_C'] < -5) & (df['Wind Speed_km/h'].between(5,10)) & (df['Visibility_km'] < 8 )]
# Out:
#                Date/Time  Temp_C  Dew Point Temp_C  Rel Hum_%  \
# 89   2012-01-04 17:00:00    -8.9             -13.2         71
# 102  2012-01-05 06:00:00    -8.2             -10.7         82
# 388  2012-01-17 04:00:00    -9.0             -12.2         78
# 389  2012-01-17 05:00:00    -8.3             -10.4         85
# 390  2012-01-17 06:00:00    -7.7              -9.9         84
# 391  2012-01-17 07:00:00    -7.5              -9.6         85
# 392  2012-01-17 08:00:00    -7.4              -9.6         84
# 510  2012-01-22 06:00:00   -19.0             -22.9         71
# 755  2012-02-01 11:00:00    -5.8              -8.3         82
# 850  2012-02-05 10:00:00   -11.1             -13.4         83
# 8722 2012-12-29 10:00:00   -12.0             -13.3         90
# 8723 2012-12-29 11:00:00   -10.9             -12.2         90
# 8737 2012-12-30 01:00:00    -9.4             -10.5         92
# 8738 2012-12-30 02:00:00    -9.3             -10.4         92
#
# ...

# %% [markdown]
# ### Q14: Convert the Temp_C column from float to int.

# %%
df['Temp_C'] = df['Temp_C'].astype(int)

# %%
df.dtypes
# Out:
# Date/Time           datetime64[ns]
# Temp_C                       int32
# Dew Point Temp_C           float64
# Rel Hum_%                    int64
# Wind Speed_km/h              int64
# Visibility_km              float64
# Press_kPa                  float64
# Weather                     object
# dtype: object

# %%
df
# Out:
#                Date/Time  Temp_C  Dew Point Temp_C  Rel Hum_%  \
# 0    2012-01-01 00:00:00      -1              -3.9         86
# 1    2012-01-01 01:00:00      -1              -3.7         87
# 2    2012-01-01 02:00:00      -1              -3.4         89
# 3    2012-01-01 03:00:00      -1              -3.2         88
# 4    2012-01-01 04:00:00      -1              -3.3         88
# ...                  ...     ...               ...        ...
# 8779 2012-12-31 19:00:00       0              -2.7         81
# 8780 2012-12-31 20:00:00       0              -2.4         83
# 8781 2012-12-31 21:00:00       0              -1.5         93
# 8782 2012-12-31 22:00:00       0              -1.8         89
# 8783 2012-12-31 23:00:00       0              -2.1         86
#
#       Wind Speed_km/h  Visibility_km  Press_kPa               Weather
# 0                   4            8.0     101.24                   Fog
# 1                   4            8.0     101.24                   Fog
# ...

# %% [markdown]
# ### Q15: State when the minimum and maximum temperature occured for each weather category.

# %%
df.groupby('Weather').min()
# Out:
#                                                   Date/Time  Temp_C  \
# Weather
# Clear                                   2012-01-03 19:00:00     -23
# Cloudy                                  2012-01-01 17:00:00     -21
# Drizzle                                 2012-01-23 21:00:00       1
# Drizzle,Fog                             2012-01-23 20:00:00       0
# Drizzle,Ice Pellets,Fog                 2012-12-17 09:00:00       0
# Drizzle,Snow                            2012-12-17 15:00:00       0
# Drizzle,Snow,Fog                        2012-12-18 21:00:00       0
# Fog                                     2012-01-01 00:00:00     -16
# Freezing Drizzle                        2012-01-07 11:00:00      -9
# Freezing Drizzle,Fog                    2012-01-01 02:00:00      -6
# Freezing Drizzle,Haze                   2012-02-01 11:00:00      -5
# Freezing Drizzle,Snow                   2012-01-13 03:00:00      -8
# Freezing Fog                            2012-01-22 06:00:00     -19
# ...

# %%
df.groupby('Weather').max()
# Out:
#                                                   Date/Time  Temp_C  \
# Weather
# Clear                                   2012-12-30 20:00:00      32
# Cloudy                                  2012-12-31 06:00:00      30
# Drizzle                                 2012-12-22 01:00:00      18
# Drizzle,Fog                             2012-12-19 10:00:00      19
# Drizzle,Ice Pellets,Fog                 2012-12-17 09:00:00       0
# Drizzle,Snow                            2012-12-19 18:00:00       1
# Drizzle,Snow,Fog                        2012-12-22 03:00:00       1
# Fog                                     2012-12-29 10:00:00      20
# Freezing Drizzle                        2012-12-17 00:00:00      -2
# Freezing Drizzle,Fog                    2012-12-10 05:00:00       0
# Freezing Drizzle,Haze                   2012-02-01 13:00:00      -5
# Freezing Drizzle,Snow                   2012-12-28 02:00:00      -3
# Freezing Fog                            2012-03-17 06:00:00       0
# ...

# %% [markdown]
# ## Checking for Statistical Trends with Visual Representation

# %% [markdown]
# #### Examine Average Monthly Temperatures over the year 2012 using the Matplotlib Library

# %% [markdown]
# In order to calculate the average monthly temperature during the year 2012, first
# convert Date/Time column from Object to Datetime datatype

# %%
df['Date/Time'] = pd.to_datetime(df['Date/Time'])

# %%
dtypes = df.dtypes.reset_index()


# Add column names 
dtypes.columns = ['Column Name', 'Data Type']

dtypes
# Out:
#         Column Name       Data Type
# 0         Date/Time  datetime64[ns]
# 1            Temp_C           int32
# 2  Dew Point Temp_C         float64
# 3         Rel Hum_%           int64
# 4   Wind Speed_km/h           int64
# 5     Visibility_km         float64
# 6         Press_kPa         float64
# 7           Weather          object

# %% [markdown]
# Calculate the monthly average temperature in 2012 using the groupby function along with the .dt.to_period method.The .dt.to_period method converts the datetime column into a specific period or frequency. Ensure that the datetime column is in a proper datetime format using pd.to_datetime(). DateTime Format is more suitable for date-based calculations. The groupby function, combined with the .dt.to_period method, enables the grouping of temperature values by month and the calculation of the mean.

# %%
#Ensure datetime column is in proper datetime format before using groupby and dt.to.period method

# %%
df.dtypes
# Out:
# Date/Time           datetime64[ns]
# Temp_C                       int32
# Dew Point Temp_C           float64
# Rel Hum_%                    int64
# Wind Speed_km/h              int64
# Visibility_km              float64
# Press_kPa                  float64
# Weather                     object
# dtype: object

# %%
#Use groupby function and dt.to.period function to calculate the mean temperature per month

# %%
monthly_avg = df.groupby(df['Date/Time'].dt.to_period('M'))['Temp_C'].mean()

# %%
#Convert monthly_avg variable from series to dataframe in order to add column names

monthly_avg = monthly_avg.reset_index()


# Add column names to the monthly_avg DataFrame
monthly_avg.columns = ['Year-Month', 'Average temperature Per Month']

# %%
monthly_avg
# Out:
#    Year-Month  Average temperature Per Month
# 0     2012-01                      -7.060484
# 1     2012-02                      -4.018678
# 2     2012-03                       2.965054
# 3     2012-04                       6.579167
# 4     2012-05                      15.795699
# 5     2012-06                      19.695833
# 6     2012-07                      22.337366
# 7     2012-08                      21.825269
# 8     2012-09                      16.048611
# 9     2012-10                      10.501344
# 10    2012-11                       0.848611
# 11    2012-12                      -3.178763

# %%
monthly_avg.dtypes
# Out:
# Year-Month                       period[M]
# Average temperature Per Month      float64
# dtype: object

# %% [markdown]
# DataType for the year-month column in the monthly average dataframe was period[M] which cant be plotted onto a line graph using
# matplotlib. In order to use this column, convert the datatype from period[M] to timestamp using the dt.to_timestamp method.
# This method converts Period objects to corresponding timestamps, which can then be used to create line plots with matplotlib. For the line graph below, we are using the Year-Month column and the Average Temperatures per month column seen above.

# %%
x = monthly_avg['Year-Month'].dt.to_timestamp()  # Convert Period to Timestamp
y = monthly_avg['Average temperature Per Month']

plt.plot(x, y)
plt.xticks(rotation=90)  # Rotate x-axis labels for better visibility
plt.xlabel('Year-Month')
plt.ylabel('Average Temperature')
plt.title('Monthly Average Temperature in 2012')
plt.tight_layout()
plt.show()

# %%
print( "The minimum monthly average temperature is -7.07 C which occurs in January 2012. The maximum monthly average temperature is 22.33 C in July 2012")
# Out:
# The minimum monthly average temperature is -7.07 C which occurs in January 2012. The maximum monthly average temperature is 22.33 C in July 2012
